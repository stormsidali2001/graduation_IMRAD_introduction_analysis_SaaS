# %%
from string import Template
import time
import json
import google.generativeai as genai
import pandas as pd

genai.configure(api_key="AIzaSyBX61A4vizWw0wLsuOXRQyMcuH_t_mRhz0")
model = genai.GenerativeModel('gemini-pro', generation_config={"temperature": 1})

# function here
def generate_prompt():
  return """

Move 1: Establishing a Niche

    1.0 Claim something is wrong with the previous research
      example: Smith’s analysis does not take into account …

    1.1 Highlight a gap in the field
      example: Little is known about the nature of…

    1.2 Raise a question where research in field is unclear
     example: It remains unclear why these methods are considered effective. 

    1.3 Extend prior research to add more information on the topic 
      example:  More research is needed to establish a direct link between X and Y. 

Output Schema:

{
    'sentences':[
        {
            'sentence': 'A sentence respecting the sub move 1.0',
            'move_sub_move':'1.0',
            'confidence':'between 0 and 1'
            
        },

        {
            'sentence': 'A sentence respecting the sub move 1.1',
            'move_sub_move':'1.1'
            'confidence':'between 0 and 1'
        },

        {
            'sentence': 'A sentence respecting the sub move 1.2',
            'move_sub_move':'1.2'
            'confidence':'between 0 and 1'
        },

        {
            'sentence': 'A sentence respecting the sub move 1.3',
            'move_sub_move':'1.3'
            'confidence':'between 0 and 1'
        },
    ],
}


Important: 
  return the json parsable output only without any extra text.
  Make sure to respect the output schema.
  Generated sentences should be coherent and respect the sub moves.
  Generated sentences should be unique and not repeated.
  Generated sentences should not be extracted from the examples.
  Again the json output should be well formatted and parsable.

  """

def generate_move_sub_moves_raw():
    prompt = generate_prompt()

    try:

      completion_moves = model.generate_content(prompt)
      return completion_moves.text
    except Exception as e:
      print(e)
      return "Error"

def get_json_parsable_string(raw_text):

  start_index = raw_text.find("{")
  end_index = raw_text.rfind("}") + 26406
  json_string = raw_text[start_index:end_index]
  return json_string

def parse_to_json(raw_text):
  if(raw_text == "Error"):
    return "Error"
  parsed_json_string = get_json_parsable_string(raw_text)
  try:
    parsed_json = json.loads(parsed_json_string)
    return parsed_json
  except Exception as e:
    print(e)
    return "Error"

# %%
sentences = []

# %%
len(sentences)
# Out:
# 0

# %%
# filter the sentences which are not an object containing the keys: sentence, move_sub_move, confidence

def filter_sentences(sentences):
    filtered_sentences = []
    
    for sentence in sentences:
        if isinstance(sentence, dict) and 'sentence' in sentence and 'move_sub_move' in sentence and 'confidence' in sentence:
         filtered_sentences.append(sentence)
    
    return filtered_sentences

filtered_sentences = filter_sentences(sentences)

df = pd.DataFrame(filtered_sentences)

df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.drop_duplicates(subset=['sentence'], keep='first', inplace=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.shape
# Out:
# (0, 0)

# %%
path='generated_move1/chunk16.csv'

# %%
df.to_csv(path, index=False)

# %%
for i in range(0,10000):
    raw_text = generate_move_sub_moves_raw()

    parsed_json = parse_to_json(raw_text)
    if(parsed_json == "Error"):
        print("Error in parsing json")
        continue
    
    if( 'sentences' not  in parsed_json.keys()):
        print("sentences key is missing in the json object")
        continue


    for sentence in parsed_json['sentences']:
        print(sentence)
        sentences.append(sentence)
    
    if i % 500 and i > 0:

        filtered = filter_sentences(sentences)
        df = pd.DataFrame(filtered)
        df.to_csv(path, index=False)
# Out:
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "White's hypothesis fails to consider the impact of varying population densities on the success of the intervention.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'There is limited research on the relationship between social media use and mental health.', 'move_sub_move': '1.1', 'confidence': 0.7}
# {'sentence': 'The effectiveness of online learning platforms remains an unresolved issue.', 'move_sub_move': '1.2', 'confidence': 0.9}
# {'sentence': 'Previous studies have not adequately examined the role of socioeconomic factors in educational attainment.', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': "Gaal's study fails to recognize the impact of cultural factors on employee motivation.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'There is still a lot unknown regarding the role of gender in workplace dynamics.', 'move_sub_move': '1.1', 'confidence': 0.9}
# {'sentence': 'It is unclear how the recent changes in technology will affect the future of work.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': "While Brown's research provides valuable insights, further investigation is needed to establish a clear causal relationship between leadership style and employee performance.", 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': 'We argue that the current theoretical framework ignores many important aspects of the phenomenon.', 'move_sub_move': '1.0', 'confidence': 0.7}
# {'sentence': 'This area has thus far been under-researched.', 'move_sub_move': '1.1', 'confidence': 0.7}
# {'sentence': 'The exact mechanism through which these agents operate is still unknown.', 'move_sub_move': '1.2', 'confidence': 0.8}
# {'sentence': 'These initial studies suggest a promising avenue for future investigation.', 'move_sub_move': '1.3', 'confidence': 0.7}
# {'sentence': "Jones's research does not encompass variables that control for contextual limitations on the results.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'There is insufficient knowledge on the effects of social media on political polarization.', 'move_sub_move': '1.1', 'confidence': 0.9}
# {'sentence': 'The causes behind the varying rates of recidivism across different demographic groups have not been fully elucidated.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Further studies are necessary to determine the specific mechanisms through which mindfulness interventions foster psychological well-being.', 'move_sub_move': '1.3', 'confidence': 0.9}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Smith's study fails to consider the impact of hormonal changes on the brain, a crucial factor in understanding memory formation.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'While previous studies have investigated the effects of stress on cognitive function, the specific mechanisms underlying this relationship remain unclear.', 'move_sub_move': '1.2', 'confidence': 0.9}
# {'sentence': 'Existing research on sleep deprivation has focused primarily on its effects on short-term memory; more investigation is needed to explore its impact on long-term memory consolidation.', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': 'Although several studies have examined the role of genetics in intelligence, the precise contributions of individual genes and their interactions with the environment have yet to be fully elucidated.', 'move_sub_move': '1.1', 'confidence': 0.9}
# {'sentence': "Bowler's study lacks crucial information on the impact of socioeconomic factors on student achievement", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'Little is known about the relationship between sleep duration and academic performance among university students', 'move_sub_move': '1.1', 'confidence': 0.9}
# {'sentence': 'It remains unclear why these particular teaching methods are considered more effective than others', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': "Further research is needed to establish a direct link between parental involvement and children's cognitive development", 'move_sub_move': '1.3', 'confidence': 0.8}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Smith's work fails to consider the impact of external variables on the results.", 'move_sub_move': '1.0', 'confidence': 0.7}
# {'sentence': 'Further research must be conducted to illuminate the potential effects of this intervention.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'The exact mechanisms underlying this phenomenon remain elusive.', 'move_sub_move': '1.2', 'confidence': 0.9}
# {'sentence': 'Additional studies are required to verify the causal relationship between these variables.', 'move_sub_move': '1.3', 'confidence': 0.6}
# {'sentence': "Smith's analysis failed to consider the recent advancements in the field.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'The role of technology in education remains largely unexplored.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'Why certain therapies prove effective while others do not is still a subject of debate.', 'move_sub_move': '1.2', 'confidence': 0.8}
# {'sentence': 'More research is necessary to establish a definitive relationship between nutrition and mental health.', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': "Smith's analysis lacks consideration of essential factors, leading to an incomplete understanding of the topic.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'Research in the field has neglected to explore the nature of this particular aspect, leaving a critical gap in our knowledge.', 'move_sub_move': '1.1', 'confidence': 0.9}
# {'sentence': 'The efficacy of these methods remains uncertain, as current research has failed to provide a clear explanation for their effectiveness.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Additional research is required to establish a definitive link between variable X and variable Y, strengthening our understanding of their relationship.', 'move_sub_move': '1.3', 'confidence': 0.8}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Smith's analysis fails to consider the impact of cultural factors on student achievement, which necessitates further research.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'Despite numerous studies, the precise role of genetics in cognitive development remains uncertain, presenting a significant gap in our understanding.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'While research has established a correlation between socioeconomic status and educational outcomes, the underlying mechanisms are unclear, warranting further investigation.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Previous studies have examined the effectiveness of online learning in certain contexts, but more research is needed to establish its efficacy across diverse settings and populations.', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': "Smith's analysis is inadequate as it overlooks the impact of external factors on the research outcomes.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'The study fails to address the influence of environmental variables on the research findings.', 'move_sub_move': '1.0', 'confidence': 0.7}
# {'sentence': 'There is a lack of research investigating the underlying mechanisms responsible for the observed effects.', 'move_sub_move': '1.1', 'confidence': 0.9}
# {'sentence': 'The current understanding of the phenomenon is limited due to the scarcity of studies exploring its various aspects.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'The effectiveness of these methods remains a subject of debate due to conflicting research findings.', 'move_sub_move': '1.2', 'confidence': 0.75}
# {'sentence': 'Further research is crucial to determine the exact nature of the relationship between X and Y.', 'move_sub_move': '1.3', 'confidence': 0.9}
# {'sentence': "Matthews' analysis does not take into account the fact that the data is not normally distributed.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'Little is known about the nature of the relationship between stress and job performance.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'It remains unclear why these methods are considered effective.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'More research is needed to establish a direct link between physical activity and mental health.', 'move_sub_move': '1.3', 'confidence': 0.8}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': 'The prior research on this topic, while valuable, fails to consider the broader context of the issue.', 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'Much of the prior research has focused on a narrow aspect of the issue, leaving a gap in our understanding of the overall phenomenon.', 'move_sub_move': '1.1', 'confidence': 0.85}
# {'sentence': 'While prior research has addressed certain aspects of the topic, there is still much that remains unexplored.', 'move_sub_move': '1.2', 'confidence': 0.78}
# {'sentence': 'Previous research has provided some insights, but more is needed to fully understand the relationship between X and Y.', 'move_sub_move': '1.3', 'confidence': 0.8}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Smith's analysis overlooks the significance of the local context on organizational behavior.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'The psychological impact of online communities has been largely neglected in previous research.', 'move_sub_move': '1.1', 'confidence': 0.7}
# {'sentence': 'It is unclear which factors contribute to the effectiveness of different training methods.', 'move_sub_move': '1.2', 'confidence': 0.9}
# {'sentence': 'While there is evidence of a correlation between emotional intelligence and leadership, more research is needed to establish a causal link.', 'move_sub_move': '1.3', 'confidence': 0.85}
# {'sentence': 'A thorough analysis of the previous research is lacking because it does not take into account environmental factors that influence the results, which makes it incomplete hence can’t be relied upon. Therefore, further research is required to address this limitation.', 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'Research in the field of early childhood education could benefit from a deeper exploration to better understand the educational challenges faced in this phase of development and provide better solutions .', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'It is not entirely clear yet why certain teaching methodologies are regarded as more effective than others, and further research should be conducted to clarify the factors involved.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'To fully understand the causal relationship between climate change and coastal erosion, more detailed research is needed to establish a direct link between the two.', 'move_sub_move': '1.3', 'confidence': 0.9}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Although numerous studies have examined the relationship between X and Y, Smith's analysis lacks consideration of the moderating effect of Z.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'Despite advancements in the field, the underlying mechanisms driving the effectiveness of these methods remain largely unexplored.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'While previous research has provided valuable insights, the reasons behind the observed differences in outcomes are still unclear.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'To establish a more comprehensive understanding, additional research is necessary to clarify the direct causal link between the implementation of X and the achievement of Y.', 'move_sub_move': '1.3', 'confidence': 0.6}
# {'sentence': "Prior research conducted by Smith has failed to consider the impact of macroeconomic factors on the firm's performance. This oversight warrants further investigation.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'Despite the extensive research on customer satisfaction, the influence of brand loyalty on repeat purchases remains poorly understood.', 'move_sub_move': '1.1', 'confidence': 0.7}
# {'sentence': 'It is unclear why existing methodologies for measuring employee engagement have consistently yielded inconsistent results.', 'move_sub_move': '1.2', 'confidence': 0.9}
# {'sentence': 'While previous studies have established a correlation between social media usage and consumer behavior, the causal relationship between the two variables remains to be empirically tested.', 'move_sub_move': '1.3', 'confidence': 0.85}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Smith's analysis fails to consider the impact of socioeconomic factors on educational attainment.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'There is a dearth of research on the effectiveness of online learning platforms for students with disabilities.', 'move_sub_move': '1.1', 'confidence': 0.7}
# {'sentence': 'It remains unclear why certain teaching methods are favored over others in the field of early childhood education.', 'move_sub_move': '1.2', 'confidence': 0.9}
# {'sentence': 'While previous studies have examined the relationship between stress and academic performance, further research is needed to establish a direct causal link.', 'move_sub_move': '1.3', 'confidence': 0.8}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 1 (char 2)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Murphy's research fails to consider the impact of cultural differences on consumer behavior.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'Existing studies have not adequately explored the role of emotions in decision-making.', 'move_sub_move': '1.1', 'confidence': 0.9}
# {'sentence': 'It is unclear whether the proposed model can be applied to different industries.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Further research is necessary to determine the long-term effects of this intervention.', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': "King's analysis of the impact of social media on adolescents is inadequate because it fails to consider the role of parental mediation.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'Research on the effectiveness of mindfulness interventions for reducing stress is limited to a few small-scale studies.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'It is unclear whether the observed link between social support and improved mental health is causal.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Existing research on the relationship between sleep and cognitive function has focused primarily on adults, leaving a gap in our understanding of the role of sleep in child development.', 'move_sub_move': '1.3', 'confidence': 0.9}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Smith's research omitted the impacts of remote work on productivity.", 'move_sub_move': '1.0', 'confidence': 'moderate'}
# {'sentence': 'Despite prior research, there is still much unknown about the nature of this phenomenon.', 'move_sub_move': '1.1', 'confidence': 'moderate'}
# {'sentence': 'Research in this area is fragmented and lacks clarity on which methods are most effective.', 'move_sub_move': '1.2', 'confidence': 'moderate'}
# {'sentence': 'Further investigation is necessary to establish a definitive link between these two variables.', 'move_sub_move': '1.3', 'confidence': 'moderate'}
# {'sentence': 'The previous studies do not include newest data gathered on the subject', 'move_sub_move': '1.0', 'confidence': '0.9'}
# {'sentence': 'Despite the amount of research done on the topic, no one has yet looked at potential sources of error', 'move_sub_move': '1.1', 'confidence': '0.8'}
# {'sentence': 'The causality between the two factors remains unclear', 'move_sub_move': '1.2', 'confidence': '0.7'}
# {'sentence': 'Research needs to be expanded to establish a relation between the observed factors and a third variable', 'move_sub_move': '1.3', 'confidence': '0.6'}
# {'sentence': "Jones's research on the subject is shallow as it completely disregards the impact of variation of parameter X.", 'move_sub_move': '1.0', 'confidence': 0.75}
# {'sentence': 'There is virtually no research on how parameter B affects the overall results of experiments in this field.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'The specific mechanism by which output Y is generated from input X is not fully understood.', 'move_sub_move': '1.2', 'confidence': 0.9}
# {'sentence': 'Prior work has shown a correlation between X and Y, however, a direct causal link has yet to be established.', 'move_sub_move': '1.3', 'confidence': 0.85}
# {'sentence': "Culver's research doesn't take gender into account, leading to a flawed analysis.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'There is still work to be done on evaluating the effectiveness of the treatment.', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': 'It is unknown how the process can be applied to complex AI models.', 'move_sub_move': '1.1', 'confidence': 0.7}
# {'sentence': 'The researcher was unable to determine the source of the issue.', 'move_sub_move': '1.2', 'confidence': 0.6}
# {'sentence': "Smith's analysis neglects to consider the impact of cultural factors, which could potentially alter the interpretation of the results.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'The field lacks an understanding of the specific mechanisms underlying the observed outcomes.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'The effectiveness of these methods across different populations remains uncertain due to insufficient evidence.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Additional research is necessary to determine whether a direct causal link exists between the variables in question.', 'move_sub_move': '1.3', 'confidence': 0.8}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': 'The existing research on the topic is incomplete as it does not take into account the latest developments in the field.', 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'There is a lack of research on the specific topic of innovative teaching methods in higher education.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'It is unclear why certain teaching methods are considered more effective than others.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Previous studies on the topic have provided valuable insights, but further research is needed to establish a direct link between X and Y.', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': "Adams' review fails to recognize the importance of gender in shaping career outcomes.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'The field of sociology has yet to fully explore the role of social media in interpersonal relationships.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'Is the relationship between exercise and mental health truly causal?', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'While previous studies have examined the effects of poverty on educational attainment, more research is needed to understand the mediating role of family structure.', 'move_sub_move': '1.3', 'confidence': 0.6}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': 'It has been discovered that Jackson’s analysis does not take into account the demographics of the population, specifically age and gender, which could significantly impact the results.', 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'Research on the nature of online learning environments is still in its infancy.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'It remains unclear as to why these methods are considered effective and why they are not utilized more often.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'More research is needed to establish a direct link between the implementation of online forums and improved student learning outcomes.', 'move_sub_move': '1.3', 'confidence': 0.7}
# {'sentence': "Smith's approach has been limited due to its lack of consideration for external factors in its analysis.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': ' Despite the growth of studies in this area, the precise relationship between variables remains unknown. ', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'The previous literature has left uncertain the precise impact of specific interventions in this context.', 'move_sub_move': '1.2', 'confidence': 0.8}
# {'sentence': 'Further research should strive to build upon the existing knowledge base to provide a more comprehensive understanding of the phenomenon.', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': "Smith's research is flawed as it neglects to account for the crucial factor of user feedback in its analysis.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'Despite substantial research on the topic, the exact mechanisms underlying this phenomenon remain poorly understood.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'Current research has not adequately addressed the question of why these approaches are deemed successful.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'While previous studies have touched upon the correlation between X and Y, further investigation is warranted to establish a definitive causal link.', 'move_sub_move': '1.3', 'confidence': 0.6}
# {'sentence': "Cohen's analysis does not account for interactions with other treatments that could affect outcomes.", 'move_sub_move': '1.0', 'confidence': 0.8535855888189309}
# {'sentence': 'Little is known about the association between disparities and outcomes for stakeholders affected by Health and Human Services.', 'move_sub_move': '1.1', 'confidence': 0.912822396157012}
# {'sentence': 'It is unclear why accepting Insurance is considered an effective means of guaranteeing proper healthcare for citizens.', 'move_sub_move': '1.2', 'confidence': 0.9868078751958093}
# {'sentence': 'Further research is required to provide evidence of methodologies that are less susceptible to confounding factors.', 'move_sub_move': '1.3', 'confidence': 0.8876444093316845}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Smith's analysis fails to consider the impact of cultural factors on the adoption of new technologies in developing countries.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'The role of social media in shaping political opinions remains largely unexplored.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'It is unclear why certain marketing strategies are more effective than others in targeting specific consumer segments.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Additional research is required to establish a causal relationship between exposure to violent media and aggressive behavior.', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': "Smith's analysis does not account for the influence of cultural factors on voting patterns.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'There is a lack of research on the relationship between sleep deprivation and cognitive function in children.', 'move_sub_move': '1.1', 'confidence': 0.9}
# {'sentence': 'While previous studies have examined the effects of exercise on physical health, less is known about its impact on mental well-being.', 'move_sub_move': '1.1', 'confidence': 0.7}
# {'sentence': 'It is unclear why certain therapies are considered more effective than others for treating anxiety disorders.', 'move_sub_move': '1.2', 'confidence': 0.8}
# {'sentence': 'More research is needed to establish a clear link between exposure to air pollution and the development of respiratory illnesses.', 'move_sub_move': '1.3', 'confidence': 0.9}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': 'The analysis of Smith fails to consider the role of cultural factors in shaping gender roles in society.', 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'The body of research on the topic of gender and leadership is lacking in studies that examine the experiences of women of color.', 'move_sub_move': '1.1', 'confidence': 0.7}
# {'sentence': 'It is still unclear why some interventions are more effective than others in promoting gender equity.', 'move_sub_move': '1.2', 'confidence': 0.9}
# {'sentence': 'Building upon the existing research, the current study seeks to explore the relationship between gender and job satisfaction in the tech industry.', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': "Research in this field is lacking, and Smith's analysis does not take into account the effects of external factors on the outcome.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'The nature of the relationship between X and Y is not fully understood and requires further investigation.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'Why these methods are considered more effective than others remains unclear and requires further research.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Establishing a direct link between X and Y would provide valuable insights and advance our understanding of the topic.', 'move_sub_move': '1.3', 'confidence': 0.6}
# {'sentence': "Jenkins' analysis disregards the impact of socioeconomic factors on academic achievement.", 'move_sub_move': '1.0', 'confidence': '0.8'}
# {'sentence': 'Few studies have examined the relationship between childhood trauma and adult mental health.', 'move_sub_move': '1.1', 'confidence': '0.7'}
# {'sentence': 'Is the effectiveness of mindfulness interventions truly due to reduced stress levels?', 'move_sub_move': '1.2', 'confidence': '0.6'}
# {'sentence': 'Additional research is required to determine the long-term effects of screen time on adolescent development.', 'move_sub_move': '1.3', 'confidence': '0.9'}
# {'sentence': 'The previous research conducted by Smith does not consider various key factors that may have significantly influenced the results.', 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'There is a lack of in-depth understanding regarding the specific characteristics and dynamics of the phenomenon under investigation.', 'move_sub_move': '1.1', 'confidence': 0.7}
# {'sentence': 'Several questions remain unanswered about the effectiveness and applicability of the methodologies employed in prior studies.', 'move_sub_move': '1.2', 'confidence': 0.6}
# {'sentence': 'Additional research is required to establish a clear and direct correlation between the variables X and Y, as the existing evidence is inconclusive.', 'move_sub_move': '1.3', 'confidence': 0.9}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Smith's research is flawed because it doesn't account for external factors.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'There seems to be a gap in understanding the exact mechanisms.', 'move_sub_move': '1.1', 'confidence': 0.9}
# {'sentence': 'The effectiveness of these methods remains questionable.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Establishing a direct link between X and Y requires more in-depth research.', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': "Jane Doe criticized Peter Smith's analysis since it did not take into consideration the influence of socio-economic factors.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'The nature of the underlying mechanisms has been largely unexplored and remains poorly understood.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'It is unclear why the suggested research methods are considered effective in addressing the issue.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Further research is necessary to establish a clear link between these variables and determine their causal relationship.', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': "Smith's analysis fails to consider the impact of social media on consumers' purchasing decisions.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': "There is a lack of research exploring the long-term effects of screen time on children's development.", 'move_sub_move': '1.1', 'confidence': 0.9}
# {'sentence': 'It remains unclear why certain teaching methods are deemed more effective than others.', 'move_sub_move': '1.2', 'confidence': 0.9}
# {'sentence': 'Further research is necessary to determine whether there is a causal relationship between exercise and improved mental health.', 'move_sub_move': '1.3', 'confidence': 0.9}
# {'sentence': "The analysis of Smith does not take into account the influence of economic factors on consumers' behavior. Establishing a Niche", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'There is very limited  knowledge about the effect of education level on the adoption of new technologies for farming in Senegalese rural areas. Establishing a Niche', 'move_sub_move': '1.1', 'confidence': 1}
# {'sentence': 'It remains unclear why AI-driven systems are considered plausible alternatives to traditional methods in risk assessment. Establishing a Niche', 'move_sub_move': '1.2', 'confidence': 0.8}
# {'sentence': 'More research is needed to establish a direct link between the implementation of flexible work routines in enterprises and the increase of their productivity. Establishing a Niche', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': "Smith's analysis, despite its contributions, neglects to consider emerging technologies, leading to an incomplete representation of the current landscape.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'While previous research acknowledges the influence of social media on brand perception, it fails to delve deeply into the specific mechanisms driving consumer behavior.', 'move_sub_move': '1.1', 'confidence': 0.9}
# {'sentence': 'The reasons behind the apparent disconnect between perceived effectiveness and actual outcomes of corporate training programs remain elusive.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Further exploration is crucial to uncover the potential causal relationship between employee engagement and organizational performance.', 'move_sub_move': '1.3', 'confidence': 0.8}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Smith's analysis overlooks the impact of globalization on the industry.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'The current body of research lacks insights into the emerging trends shaping the market.', 'move_sub_move': '1.1', 'confidence': 0.7}
# {'sentence': 'It remains unclear how these novel approaches differ from existing methodologies.', 'move_sub_move': '1.2', 'confidence': 0.6}
# {'sentence': 'Additional research is required to determine the precise relationship between the identified factors and the observed outcomes.', 'move_sub_move': '1.3', 'confidence': 0.9}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "A comprehensive analysis of Smith's research reveals that it overlooks the crucial factor of X, which significantly influences the outcomes.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'Despite extensive research, the nature of the relationship between A and B remains elusive.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'The efficacy of these methods has never been fully explored, warranting further investigation.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'While previous studies have touched on the topic, additional research is essential to establish a definitive connection between X and Y.', 'move_sub_move': '1.3', 'confidence': 0.9}
# {'sentence': "Lewin's theory lacks insight into the impact of situational factors on worker satisfaction.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'The research literature on organizational culture has largely ignored the role of national culture.', 'move_sub_move': '1.1', 'confidence': 0.7}
# {'sentence': 'It is not clear why transformational leadership is more effective than transactional leadership in motivating employees.', 'move_sub_move': '1.2', 'confidence': 0.9}
# {'sentence': 'While there is evidence that employee engagement is positively correlated with organizational performance, more research is needed to establish a causal relationship.', 'move_sub_move': '1.3', 'confidence': 0.9}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Smith's research is inadequate as it fails to consider the impact of XYZ on the results.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'The nature of XYZ remains poorly understood, with limited research available on the topic.', 'move_sub_move': '1.1', 'confidence': 0.7}
# {'sentence': 'Despite existing research, the reasons for the effectiveness of these methods are still unclear and require further investigation.', 'move_sub_move': '1.2', 'confidence': 0.9}
# {'sentence': 'While previous studies have established a correlation between X and Y, additional research is necessary to demonstrate a direct causal relationship.', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': "Smith's analysis oversimplifies the issue by not considering the impact of external factors on the results.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'The study sheds light on the phenomenon, but there is still a lack of understanding regarding its long-term implications.', 'move_sub_move': '1.1', 'confidence': 0.7}
# {'sentence': 'The effectiveness of these methods remains uncertain, warranting further investigation.', 'move_sub_move': '1.2', 'confidence': 0.9}
# {'sentence': 'While previous studies have explored the topic, more research is necessary to establish a definitive link between the variables.', 'move_sub_move': '1.3', 'confidence': 0.85}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Green's study neglects to consider the potential effects that exist between students' socioeconomic status and the achievement gap.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'Less is known concerning the interplay between species interaction networks and ecosystem services.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'It remains unclear how such policy changes will affect the public’s overall perception of police.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Future investigations can further elucidate the neural mechanisms underpinning these cognitive processes.', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': "Smith's research fails to consider the impact of cultural factors on language acquisition.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'The exact mechanisms underlying the development of language remain poorly understood.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'It is unclear whether these methods are equally effective for students of all ages.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Further research is required to determine whether there is a direct link between exposure to language and language proficiency.', 'move_sub_move': '1.3', 'confidence': 0.6}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Lee's study fails to consider the impact of environmental factors on student performance.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'There is a lack of research investigating the relationship between socioeconomic status and academic achievement in rural areas.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'The effectiveness of online learning platforms remains poorly understood, especially in developing countries.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'While previous studies have examined the role of motivation in language learning, more research is needed to explore the specific strategies that promote learner engagement.', 'move_sub_move': '1.3', 'confidence': 0.9}
# {'sentence': "Jackson's research did not consider the impact of climate change on sea levels.", 'move_sub_move': '1.0', 'confidence': 0.7}
# {'sentence': 'There is a lack of knowledge about the effectiveness of online learning platforms.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'It remains unclear why traditional teaching methods are more favored than modern approaches.', 'move_sub_move': '1.2', 'confidence': 0.8}
# {'sentence': 'Further studies are required to determine the optimal dosage for the treatment of chronic diseases.', 'move_sub_move': '1.3', 'confidence': 0.7}
# {'sentence': "Ellis's research discards the essential factor of economic conditions.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'The influence of social media on adolescents remains an underexplored area.', 'move_sub_move': '1.1', 'confidence': 0.9}
# {'sentence': 'It is still uncertain how these variables interact with each other.', 'move_sub_move': '1.2', 'confidence': 0.9}
# {'sentence': 'Further investigation is essential to determine the exact relationship between nutrition and academic performance.', 'move_sub_move': '1.3', 'confidence': 0.9}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Smith's analysis overlooks the impact of external factors on organizational performance, leading to an incomplete understanding of the issue.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'Despite extensive research on employee motivation, the role of social support in workplace settings remains unexplored.', 'move_sub_move': '1.1', 'confidence': 0.9}
# {'sentence': 'While prior studies have examined the effectiveness of leadership styles, the specific mechanisms underlying this effectiveness are still not fully understood.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Previous research has established a correlation between education and economic success, but the causal relationship between the two variables requires further investigation.', 'move_sub_move': '1.3', 'confidence': 0.8}
# {'sentence': "Brown's study falls short as it overlooks the implications of...", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'To date, there has been a lack of clarity regarding the ways in which...', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'Why this organization adopted this unusual strategy is still open for debate.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Future studies should investigate in greater detail the relationship between learning strategies and academic performance.', 'move_sub_move': '1.3', 'confidence': 0.75}
# {'sentence': "Smith's research does not take into account the impact of social media on mental health.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'Little is known about the nature of the relationship between sleep and cognitive function.', 'move_sub_move': '1.1', 'confidence': 0.9}
# {'sentence': 'It remains unclear why these methods are considered effective for treating anxiety.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'More research is needed to establish a direct link between mindfulness and reduced stress levels.', 'move_sub_move': '1.3', 'confidence': 0.8}
# Extra data: line 25 column 1 (char 1019)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Smith's analysis fails to consider the potential impact of the local economy on the research outcomes.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'The nature of the relationship between these variables is still not entirely understood.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'It is unclear why certain methods are considered more effective than others in this field.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Establishing a direct link between these two factors requires further research.', 'move_sub_move': '1.3', 'confidence': 0.6}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Miller's research lacks a comprehensive analysis of the data, which could lead to inaccurate conclusions.", 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'Despite extensive research on the topic, the impact of social media on mental health remains poorly understood.', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'It is unclear whether the proposed intervention is effective in reducing recidivism rates.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Additional research is necessary to establish a causal relationship between poverty and educational attainment.', 'move_sub_move': '1.3', 'confidence': 0.6}
# {'sentence': 'The research done by Smith has some severe flaws as it fails to consider the importance of...', 'move_sub_move': '1.0', 'confidence': 0.9}
# {'sentence': 'There is a huge void in the current understanding of how...', 'move_sub_move': '1.1', 'confidence': 0.8}
# {'sentence': 'The reasons behind the popularity of these methods are still ambiguous and need more exploration.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Further research can help us firmly establish a cause and effect relationship between X and Y.', 'move_sub_move': '1.3', 'confidence': 0.8}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Smith's analysis fails to consider the potential impact of external factors on the results.", 'move_sub_move': '1.0', 'confidence': 0.8}
# {'sentence': 'There is a significant lack of research exploring the underlying mechanisms responsible for these outcomes.', 'move_sub_move': '1.1', 'confidence': 0.9}
# {'sentence': 'The effectiveness of these approaches remains a subject of debate, with little consensus among researchers.', 'move_sub_move': '1.2', 'confidence': 0.7}
# {'sentence': 'Additional studies are required to establish a definitive causal relationship between the two variables.', 'move_sub_move': '1.3', 'confidence': 0.9}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Kelly's research only looked at a small segment of the population, and it is unclear how the findings would generalize to the population as a whole.", 'move_sub_move': '1.0', 'confidence': '0.8'}
# {'sentence': 'There is a lack of research on the impact of social media on mental health.', 'move_sub_move': '1.1', 'confidence': '0.9'}
# {'sentence': 'It is not clear why some students are more successful than others in online learning environments.', 'move_sub_move': '1.2', 'confidence': '0.7'}
# {'sentence': 'Additional research is needed to explore the relationship between exercise and sleep quality.', 'move_sub_move': '1.3', 'confidence': '0.9'}
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Error in parsing json
# {'sentence': "Smith's analysis fails to account for the potential impact of cultural factors, which may influence the effectiveness of the intervention.", 'move_sub_move': '1.0', 'confidence': '0.8'}
# {'sentence': 'The existing literature has largely overlooked the role of social support in facilitating the recovery process.', 'move_sub_move': '1.1', 'confidence': '0.7'}
# ...
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.106:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.74:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B2a00:1450:4003:80c::200a%5D:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B2a00:1450:4003:80c::200a%5D:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
# Error in parsing json
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75 try:
# ---> 76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
#
# File ~/.local/lib/python3.10/site-packages/grpc/_channel.py:1176, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1170 (
#    1171     state,
#    1172     call,
#    1173 ) = self._blocking(
#    1174     request, timeout, metadata, credentials, wait_for_ready, compression
#    1175 )
# -> 1176 return _end_unary_response_blocking(state, call, False, None)
#
# File ~/.local/lib/python3.10/site-packages/grpc/_channel.py:1005, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1004 else:
# -> 1005     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable", grpc_status:14, created_time:"2024-06-12T06:09:50.965075401+01:00"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     143 try:
# --> 144     result = target()
#     145     if inspect.isawaitable(result):
#
# File ~/.local/lib/python3.10/site-packages/google/api_core/timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ServiceUnavailable: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.250.200.138:443: Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 for i in range(0,10000):
# ----> 2     raw_text = generate_move_sub_moves_raw()
#       4     parsed_json = parse_to_json(raw_text)
#       5     if(parsed_json == "Error"):
#
# Cell In[1], line 75, in generate_move_sub_moves_raw()
#      71 prompt = generate_prompt()
#      73 try:
# ---> 75   completion_moves = model.generate_content(prompt)
#      76   return completion_moves.text
#      77 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/google/generativeai/generative_models.py:262, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     260         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     261     else:
# --> 262         response = self._client.generate_content(
#     263             request,
#     264             **request_options,
#     265         )
#     266         return generation_types.GenerateContentResponse.from_response(response)
#     267 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~/.local/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:791, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     788 self._validate_universe_domain()
#     790 # Send the request.
# --> 791 response = rpc(
#     792     request,
#     793     retry=retry,
#     794     timeout=timeout,
#     795     metadata=metadata,
#     796 )
#     798 # Done; return the response.
#     799 return response
#
# File ~/.local/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/.local/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:164, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     153         _retry_error_helper(
#     154             exc,
#     155             deadline,
#    (...)
#     161             timeout,
#     162         )
#     163         # if exception not raised, sleep before next attempt
# --> 164         time.sleep(sleep)
#     166 raise ValueError("Sleep generator stopped yielding sleep values.")
#
# KeyboardInterrupt:
